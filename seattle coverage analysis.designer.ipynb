# %%
"""
id: source_0
template: source
templateVersion: 1.0.0
name: cell_towers
position:
  x: 600
  y: 232.5
description:
  text: Load all data from the specified table of cell towers.
  hash: af8bed04
previewCodeHash: 1a7b4890704877a5
previewMode: "1000"
config:
  table_source:
    tableName: cmegdemos_catalog.network_analytics_enablement.cell_towers
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "table_source": {
        "tableName": "cmegdemos_catalog.network_analytics_enablement.cell_towers"
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["source_0.data"] = out["data"]

# %%
"""
id: source_1
template: source
templateVersion: 1.0.0
name: fcc_bdc_h3_seattle
position:
  x: 300
  y: 155
description:
  text: Load all data from the specified table.
  hash: e038fe46
previewCodeHash: 9712e131b5bbaef5
previewMode: "1000"
config:
  table_source:
    tableName: cmegdemos_catalog.network_analytics_enablement.fcc_bdc_h3_seattle
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "table_source": {
        "tableName": "cmegdemos_catalog.network_analytics_enablement.fcc_bdc_h3_seattle"
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["source_1.data"] = out["data"]

# %%
"""
id: source_2
template: source
templateVersion: 1.0.0
name: building_footprints
position:
  x: 0
  y: 0
description:
  text: Load data from the specified catalog table.
  hash: 13fa78ea
previewCodeHash: 4ea1bca1bc56bc64
previewMode: "1000"
config:
  table_source:
    tableName: cmegdemos_catalog.network_analytics_enablement.building_footprints
input: []
"""

# generated from the system
from typing import Dict, Any

def _strip_sql_quotes(s):
    if isinstance(s, str) and len(s) >= 2:
        if (s[0] == '"' and s[-1] == '"') or (s[0] == "'" and s[-1] == "'"):
            return s[1:-1]
    return s

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    file_source = config.get("file_source")
    table_source = config.get("table_source")

    if file_source:
        path = file_source.get("path")
        if not path:
            raise ValueError("Source: 'path' is required for file source")
        options = []
        for key, value in file_source.items():
            if key == "path":
                continue
            if key == "headerRows" and isinstance(value, bool):
                options.append(f"{key}=>{1 if value else 0}")
            elif isinstance(value, bool):
                options.append(f'{key}=>{"true" if value else "false"}')
            elif isinstance(value, (int, float)):
                options.append(f"{key}=>{value}")
            else:
                clean = _strip_sql_quotes(str(value))
                if key == "dataAddress" and clean.startswith("!"):
                    clean = clean[1:]
                options.append(f'{key}=>"{clean}"')
        opts = ", ".join(options)
        sql = f'SELECT * FROM read_files("{path}", {opts})' if opts else f'SELECT * FROM read_files("{path}")'
        out = spark.sql(sql)
    elif table_source:
        table_name = table_source.get("tableName")
        if not table_name:
            raise ValueError("Source: 'tableName' is required for table source")
        out = spark.table(table_name)
    else:
        raise ValueError("Source: either 'file_source' or 'table_source' must be configured")

    return {"data": out}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "table_source": {
        "tableName": "cmegdemos_catalog.network_analytics_enablement.building_footprints"
    }
}
inputs = {}
out = run(config, inputs, spark)
ctx["source_2.data"] = out["data"]

# %%
"""
id: compute_h3
template: transform
templateVersion: 1.0.0
name: compute_h3
position:
  x: 300
  y: 0
description:
  text: Keep building id, height, geometry, and add a column with H3 resolution 9 index of the geometry centroid.
  hash: deec53bb
previewCodeHash: 572d57e725b5b34e
previewMode: "1000"
config:
  expressions:
    - building_id
    - height
    - geometry
    - h3_h3tostring(h3_pointash3(ST_AsText(ST_Centroid(geometry)), 9)) AS `h3_res9_id`
input:
  - node: source_2
    input_port: data
    output_port: data
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])

    if not expressions:
        return {"transformed_data": df}

    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "building_id",
        "height",
        "geometry",
        "h3_h3tostring(h3_pointash3(ST_AsText(ST_Centroid(geometry)), 9)) AS `h3_res9_id`"
    ]
}
inputs = {
    "data": ctx["source_2.data"]
}
out = run(config, inputs, spark)
ctx["compute_h3.transformed_data"] = out["transformed_data"]

# %%
"""
id: join_buildings_coverage
template: join
templateVersion: 1.0.0
name: join_buildings_coverage
position:
  x: 600
  y: 77.5
description:
  text: Join two tables on h3_res9_id and keep specific columns from both.
  hash: 0a5aed45
previewCodeHash: 3fcb00b3da5eb39f
previewMode: "1000"
config:
  join_type: inner
  join_conditions: left.h3_res9_id = right.h3_res9_id
  expressions:
    - "`left`.building_id"
    - "`left`.height"
    - "`left`.geometry"
    - "`left`.h3_res9_id"
    - "`right`.technology"
    - "`right`.mindown"
    - "`right`.minup"
    - "`right`.environmnt"
input:
  - node: compute_h3
    input_port: left
    output_port: transformed_data
  - node: source_1
    input_port: right
    output_port: data
"""

# generated from the system
from typing import Dict, Any, List
import pyspark.sql.functions as F

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    join_type = config.get("join_type", "inner").replace(" ", "_")
    join_condition = config.get("join_conditions", "")
    expressions: List[str] = config.get("expressions", [])

    # Alias DataFrames with fixed names so that table-qualified column
    # references in join_conditions and expressions always resolve.
    # The TS serializer emits "left.col" / "right.col" regardless of the
    # actual table names, so these aliases must match exactly.
    df_left = inputs.get("left")
    df_right = inputs.get("right")
    if df_left is None or df_right is None:
        raise ValueError("Both left and right inputs must be connected")
    df_left = df_left.alias("left")
    df_right = df_right.alias("right")

    # join_condition is a plain SQL expression string serialized by the TS
    # side (same pattern as filter's condition field).
    if not join_condition:
        result = df_left.join(df_right, how=join_type)
    else:
        result = df_left.join(df_right, F.expr(join_condition), how=join_type)

    # Apply optional SELECT expressions
    if expressions:
        result = result.selectExpr(*expressions)

    return {"joined_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "join_type": "inner",
    "join_conditions": "left.h3_res9_id = right.h3_res9_id",
    "expressions": [
        "`left`.building_id",
        "`left`.height",
        "`left`.geometry",
        "`left`.h3_res9_id",
        "`right`.technology",
        "`right`.mindown",
        "`right`.minup",
        "`right`.environmnt"
    ]
}
inputs = {
    "left": ctx["compute_h3.transformed_data"],
    "right": ctx["source_1.data"]
}
out = run(config, inputs, spark)
ctx["join_buildings_coverage.joined_data"] = out["joined_data"]

# %%
"""
id: nearest_tower_distance
template: sql
templateVersion: 1.0.0
name: nearest_tower_distance
position:
  x: 900
  y: 155
description:
  text: Find the nearest cell tower to each building per technology with distance and tower details.
  hash: f9dfed90
previewCodeHash: 2c4282de41ec8d04
previewMode: "1000"
config:
  query: |
    SELECT
      b.building_id,
      b.height,
      b.geometry,
      b.h3_res9_id,
      b.technology,
      b.mindown,
      b.minup,
      b.environmnt,
      t.tower_id AS nearest_tower_id,
      t.carrier AS nearest_tower_carrier,
      t.tower_type AS nearest_tower_type,
      t.coverage_radius_m,
      ST_DistanceSphere(ST_Centroid(b.geometry), t.location) AS distance_to_nearest_tower_m
    FROM (
      SELECT
        *,
        ROW_NUMBER() OVER (
          PARTITION BY building_id, technology
          ORDER BY ST_DistanceSphere(ST_Centroid(geometry), tower_location) ASC
        ) AS rn
      FROM (
        SELECT
          jbc.*,
          ct.tower_id AS tower_id,
          ct.carrier AS carrier,
          ct.tower_type AS tower_type,
          ct.coverage_radius_m AS coverage_radius_m,
          ct.location AS tower_location
        FROM join_buildings_coverage jbc
        CROSS JOIN cell_towers ct
      )
    ) b
    JOIN cell_towers t ON b.tower_id = t.tower_id
    WHERE b.rn = 1
input:
  - node: join_buildings_coverage
    input_port: data
    output_port: joined_data
  - node: source_0
    input_port: data
    output_port: data
"""

# generated from the system
import re
from typing import Any, Dict, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    sources: List[Dict[str, str]] = inputs.get("data__sources") or []
    for i, df in enumerate(inputs.get("data") or []):
        if df is not None and i < len(sources):
            df.createOrReplaceTempView(sources[i]["df_name"])
            globals().setdefault("_lb_views", set()).add(sources[i]["df_name"])

    query = config.get("query", "")
    param_names = set(re.findall(r"(?<!:):(\w+)", query))
    if param_names:
        all_widgets = dbutils.widgets.getAll()
        args = {name: all_widgets[name] for name in param_names if name in all_widgets}
        result = spark.sql(query, args=args) if args else spark.sql(query)
    else:
        result = spark.sql(query)
    return {"result": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "query": "SELECT\n  b.building_id,\n  b.height,\n  b.geometry,\n  b.h3_res9_id,\n  b.technology,\n  b.mindown,\n  b.minup,\n  b.environmnt,\n  t.tower_id AS nearest_tower_id,\n  t.carrier AS nearest_tower_carrier,\n  t.tower_type AS nearest_tower_type,\n  t.coverage_radius_m,\n  ST_DistanceSphere(ST_Centroid(b.geometry), t.location) AS distance_to_nearest_tower_m\nFROM (\n  SELECT\n    *,\n    ROW_NUMBER() OVER (\n      PARTITION BY building_id, technology\n      ORDER BY ST_DistanceSphere(ST_Centroid(geometry), tower_location) ASC\n    ) AS rn\n  FROM (\n    SELECT\n      jbc.*,\n      ct.tower_id AS tower_id,\n      ct.carrier AS carrier,\n      ct.tower_type AS tower_type,\n      ct.coverage_radius_m AS coverage_radius_m,\n      ct.location AS tower_location\n    FROM join_buildings_coverage jbc\n    CROSS JOIN cell_towers ct\n  )\n) b\nJOIN cell_towers t ON b.tower_id = t.tower_id\nWHERE b.rn = 1\n"
}
inputs = {
    "data": [
        ctx["join_buildings_coverage.joined_data"],
        ctx["source_0.data"]
    ],
    "data__sources": [
        {
            "node": "join_buildings_coverage",
            "output_port": "joined_data",
            "name": "join_buildings_coverage",
            "df_name": "join_buildings_coverage"
        },
        {
            "node": "source_0",
            "output_port": "data",
            "name": "cell_towers",
            "df_name": "cell_towers"
        }
    ]
}
out = run(config, inputs, spark)
ctx["nearest_tower_distance.result"] = out["result"]

# %%
"""
id: distance_buckets
template: transform
templateVersion: 1.0.0
name: distance_buckets
position:
  x: 1200
  y: 232.5
description:
  text: Create a new column grouping distances into buckets and keep selected columns.
  hash: 15af3715
previewCodeHash: a34966bf5e8d9cc3
previewMode: "1000"
config:
  expressions:
    - mindown
    - minup
    - distance_to_nearest_tower_m
    - CASE WHEN distance_to_nearest_tower_m < 500 THEN '0-500m' WHEN distance_to_nearest_tower_m < 1000 THEN '500-1000m' WHEN distance_to_nearest_tower_m < 2000 THEN '1000-2000m' WHEN distance_to_nearest_tower_m < 3000 THEN '2000-3000m' ELSE '3000m+' END AS `distance_bucket`
input:
  - node: nearest_tower_distance
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any, List

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    expressions: List[str] = config.get("expressions", [])

    if not expressions:
        return {"transformed_data": df}

    return {"transformed_data": df.selectExpr(*expressions)}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "expressions": [
        "mindown",
        "minup",
        "distance_to_nearest_tower_m",
        "CASE WHEN distance_to_nearest_tower_m < 500 THEN '0-500m' WHEN distance_to_nearest_tower_m < 1000 THEN '500-1000m' WHEN distance_to_nearest_tower_m < 2000 THEN '1000-2000m' WHEN distance_to_nearest_tower_m < 3000 THEN '2000-3000m' ELSE '3000m+' END AS `distance_bucket`"
    ]
}
inputs = {
    "data": ctx["nearest_tower_distance.result"]
}
out = run(config, inputs, spark)
ctx["distance_buckets.transformed_data"] = out["transformed_data"]

# %%
"""
id: output_final
template: output
templateVersion: 1.0.0
name: cmegdemos_catalog.network_analytics_enablement.downtown_seattle_building_coverage_designer
position:
  x: 1200
  y: 77.5
description:
  text: Save data by overwriting the specified table in the catalog and schema.
  hash: c9c6ccbf
previewCodeHash: dc2158eb49b9e039
previewMode: "1000"
config:
  catalog: cmegdemos_catalog
  schema: network_analytics_enablement
  table_name: downtown_seattle_building_coverage_designer
input:
  - node: nearest_tower_distance
    input_port: data
    output_port: result
"""

# generated from the system
from typing import Dict, Any

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs["data"]
    catalog = config.get("catalog", "")
    schema = config.get("schema", "")
    table_name = config.get("table_name", "")

    if not table_name:
        raise ValueError("Output: 'table_name' is required")

    parts = [p for p in [catalog, schema, table_name] if p]
    full_name = ".".join(parts)

    df.write.mode("overwrite").saveAsTable(full_name)

    return {}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "catalog": "cmegdemos_catalog",
    "schema": "network_analytics_enablement",
    "table_name": "downtown_seattle_building_coverage_designer"
}
inputs = {
    "data": ctx["nearest_tower_distance.result"]
}
out = run(config, inputs, spark)

# %%
"""
id: agg_by_distance
template: aggregate
templateVersion: 1.0.0
name: agg_by_distance
position:
  x: 1500
  y: 232.5
description:
  text: Group data by distance bucket and calculate average, minimum, and maximum of mindown and minup, plus count buildings in each bucket.
  hash: a8e7a5df
previewCodeHash: 0ff6cf2cc48868e1
previewMode: "1000"
config:
  group_bys:
    - expr: distance_bucket
      type: expr
  aggregations:
    - columnExpr:
        expr: mindown
        type: expr
      fn: AVG
      alias: avg_mindown
    - columnExpr:
        expr: minup
        type: expr
      fn: AVG
      alias: avg_minup
    - columnExpr:
        expr: mindown
        type: expr
      fn: MIN
      alias: min_mindown
    - columnExpr:
        expr: mindown
        type: expr
      fn: MAX
      alias: max_mindown
    - columnExpr:
        expr: minup
        type: expr
      fn: MIN
      alias: min_minup
    - columnExpr:
        expr: minup
        type: expr
      fn: MAX
      alias: max_minup
    - columnExpr:
        expr: distance_bucket
        type: expr
      fn: COUNT
      alias: building_count
input:
  - node: distance_buckets
    input_port: data
    output_port: transformed_data
"""

# generated from the system
import math
from typing import Dict, Any
import pyspark.sql.functions as F

# Default percentile (median). Used as a fallback when a PERCENTILE aggregation
# is missing or has a non-numeric / non-finite percentage. Mirrors
# DEFAULT_PERCENTILE_VALUE in AggregateNodeViewModel.ts so SQL and Python
# pipelines agree on the default.
DEFAULT_PERCENTILE = 0.5

def run(
    config: Dict[str, Any], inputs: Dict[str, Any], spark
) -> Dict[str, Any]:
    df = inputs.get("data")
    group_bys = config.get("group_bys", [])
    aggregations = config.get("aggregations", [])

    group_by_set = set(e for gb in group_bys if (e := gb.get("expr", "")))

    agg_exprs = []
    for agg_def in aggregations:
        col_expr = agg_def.get("columnExpr", {})
        raw_expr = col_expr.get("expr", "")
        fn = agg_def.get("fn", "-")
        alias = agg_def.get("alias")

        # Skip pass-through columns that duplicate a group-by column;
        # groupBy() already includes them in the output.
        if (fn == "-" or fn == "_") and not alias and raw_expr in group_by_set:
            continue

        fn_map = {
            "SUM": F.sum,
            "AVG": F.avg,
            "COUNT": F.count,
            "MIN": F.min,
            "MAX": F.max,
            "MEAN": F.mean,
            "MEDIAN": F.median,
            "STDDEV": F.stddev,
            "VARIANCE": F.variance,
        }

        agg_fn = fn_map.get(fn)
        if agg_fn:
            col = agg_fn(raw_expr)
        elif fn == "-" or fn == "_":
            col = F.col(raw_expr)
        elif fn == "PERCENTILE":
            # Spark PERCENTILE requires (col, percentage [, frequency]) with percentage
            # in [0, 1]; emitting PERCENTILE(col) triggers WRONG_NUM_ARGS at analysis
            # time. For finite numeric inputs we clamp to [0, 1] (mirroring the V1/V2
            # input clamps) so out-of-range values like -0.1 or 1.5 — typos or stale
            # frontend state — become a valid boundary instead of silently overriding
            # the user's intent with the median. Non-numeric, non-finite, boolean, or
            # missing values fall back to DEFAULT_PERCENTILE.
            raw_pct = agg_def.get("percentage")
            if (
                isinstance(raw_pct, (int, float))
                and not isinstance(raw_pct, bool)
                and math.isfinite(raw_pct)
            ):
                pct = max(0.0, min(1.0, float(raw_pct)))
            else:
                pct = DEFAULT_PERCENTILE
            col = F.expr(f"PERCENTILE({raw_expr}, {pct})")
        else:
            col = F.expr(f"{fn}({raw_expr})")

        if alias:
            col = col.alias(alias)

        agg_exprs.append(col)

    group_cols = [
        gb.get("expr", "") for gb in group_bys if gb.get("expr", "")
    ]

    if not agg_exprs:
        if group_cols:
            result = df.select(*group_cols).distinct()
            return {"aggregated_data": result}
        return {"aggregated_data": df}

    if group_cols:
        result = df.groupBy(*group_cols).agg(*agg_exprs)
    else:
        result = df.agg(*agg_exprs)

    return {"aggregated_data": result}

# generated from the system
ctx = globals().setdefault("ctx", {})
config = {
    "group_bys": [
        {
            "expr": "distance_bucket",
            "type": "expr"
        }
    ],
    "aggregations": [
        {
            "columnExpr": {
                "expr": "mindown",
                "type": "expr"
            },
            "fn": "AVG",
            "alias": "avg_mindown",
            "withAsKeyword": None
        },
        {
            "columnExpr": {
                "expr": "minup",
                "type": "expr"
            },
            "fn": "AVG",
            "alias": "avg_minup",
            "withAsKeyword": None
        },
        {
            "columnExpr": {
                "expr": "mindown",
                "type": "expr"
            },
            "fn": "MIN",
            "alias": "min_mindown",
            "withAsKeyword": None
        },
        {
            "columnExpr": {
                "expr": "mindown",
                "type": "expr"
            },
            "fn": "MAX",
            "alias": "max_mindown",
            "withAsKeyword": None
        },
        {
            "columnExpr": {
                "expr": "minup",
                "type": "expr"
            },
            "fn": "MIN",
            "alias": "min_minup",
            "withAsKeyword": None
        },
        {
            "columnExpr": {
                "expr": "minup",
                "type": "expr"
            },
            "fn": "MAX",
            "alias": "max_minup",
            "withAsKeyword": None
        },
        {
            "columnExpr": {
                "expr": "distance_bucket",
                "type": "expr"
            },
            "fn": "COUNT",
            "alias": "building_count",
            "withAsKeyword": None
        }
    ]
}
inputs = {
    "data": ctx["distance_buckets.transformed_data"]
}
out = run(config, inputs, spark)
ctx["agg_by_distance.aggregated_data"] = out["aggregated_data"]
