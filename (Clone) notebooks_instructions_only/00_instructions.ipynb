# %% [markdown]
# links where I downloaded data:
# - https://broadbandmap.fcc.gov/data-download/nationwide-data?version=jun2025&pubDataVer=jun2025
# - https://wiki.openstreetmap.org/wiki/Microsoft_Building_Footprint_Data
# - https://community.opencellid.org/t/how-to-download-cells-database-csv/22
#
#
# get access to a catalog, create your own schema, upload these datasets to a volume called raw_data and update instructions in next notebook cells with this info
